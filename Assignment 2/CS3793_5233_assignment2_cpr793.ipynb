# %% [markdown]
# # UTSA CS 3793/5233: Assignment-2
#
# Summer 2021
#
#
# **Hasanul Mahmud -cpr793**

# %% [markdown]
# ## Learning Objectives
#
#
#
# *   Game Playing
# *   Chess - Board Setup & Rules
# *   Adversarial Search
# *   AI - Random vs MinMax

# %% [markdown]
# ## Description
#
# This assignment is focused on **game playing** and creating a proper **AI for chess**.
# In the following sections, you will complete a series of tasks to create a chess game board, rules for each chess piece, a Random AI and a MinMax AI that plays a game of chess for both players (white and black).
#
# The base structure of the code is provided. You are supposed to write code for each of the functions. Comments are provided on what should be done. You **CANNOT** use a complete chess library and change the base code structure completely. However, you **CAN** change the code layout and name/format of the functions.

# %% [markdown]
# #Chess Board Setup & Rules
#
# In this section, you will write code to import the necessary libraries and create:
#
# 1.   **ChessBoard** - This part will contain code to initialize the board, draw the board, get the board state and move piece.
# 2.   **ChessRules** - This part will contain code for the chess rules for each piece.

# %% [markdown]
# ##Import Libraries
#
# The code here will contain only **import** statements. A base list of the required libraries are already imported. You will most likely not need any other libraries, but if needed, add the import statements here. As mentioned before, you can not use any premade chess libraries.

# %%
# your code goes here
import string
import random
import os
import sys
import time
import numpy as np
from IPython.display import clear_output
import math
print("Hasan")
# Out:
# Hasan

# %% [markdown]
# ##ChessBoard
#
# (10 points)
#
# Fill the code in the code structure provided below for the ChessBoard. The main use of this code block write functions to initialize the board, draw the board, get the board state and move piece. You can add any other functions if needed.

# %%
# you can add/change the input parameters for each function 
# you can change the function names and also add more functions if needed
def ChessBoardSetup():
    # initialize and return a chess board - create a 2D 8x8 array that has the value for each cell
    # USE the following characters for the chess pieces - lower-case for BLACK and upper-case for WHITE
    # . for empty board cell
    # p/P for pawn
    # r/R for rook
    # t/T for knight
    # b/B for bishop
    # q/Q for queen
    # k/K for king
    #for 8 columns and 8 rows
    '''
    first_row = 'rtbqkbtr'
    second_row = 'p'*8
    empty_row = '.'*8
    board = [
        list(first_row),
        list(second_row),
        list(empty_row),
        list(empty_row),
        list(empty_row),
        list(empty_row),
        list(second_row.upper()),
        list(first_row.upper())
    ]
    print(board)
    '''
    a = ['r', 'p', '.', '.', '.', '.', 'P', 'R'] 
    b = ['t', 'p', '.', '.', '.', '.', 'P', 'T'] 
    c = ['b', 'p', '.', '.', '.', '.', 'P', 'B'] 
    d = ['q', 'p', '.', '.', '.', '.', 'P', 'Q']
    e = ['k', 'p', '.', '.', '.', '.', 'P', 'K']
    f = ['b', 'p', '.', '.', '.', '.', 'P', 'B']
    g = ['t', 'p', '.', '.', '.', '.', 'P', 'T']
    h = ['r', 'p', '.', '.', '.', '.', 'P', 'R']
    #arranging the chess board
    #board
    board = np.column_stack([a, b, c, d, e, f, g, h])
    return board
#setting the chess board
board = ChessBoardSetup()

def DrawBoard():
  print(board)
#function for moving from_piece and to_piece
def MovePiece(from_piece,to_piece):
    move = board[from_piece[0],from_piece[1]]
    board[to_piece[0],to_piece[1]] = move
    board[from_piece[0],from_piece[1]] = '.'
    return board
print("Drawing the board here\n")
#DrawBoard function
DrawBoard()
# Out:
# Drawing the board here
#
# [['r' 't' 'b' 'q' 'k' 'b' 't' 'r']
#  ['p' 'p' 'p' 'p' 'p' 'p' 'p' 'p']
#  ['.' '.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.' '.']
#  ['P' 'P' 'P' 'P' 'P' 'P' 'P' 'P']
#  ['R' 'T' 'B' 'Q' 'K' 'B' 'T' 'R']]

# %% [markdown]
# ##ChessRules
#
# (60 points)
#
# Fill the code in the code structure provided below for ChessRules. The main use of the code block is to write functions to design the rules for movement of each piece on the board. This block will also contain the function to check if the current player is in check, check-mate. You can also have functions that can return the current player's pieces that have legal moves in the current board state.
#
# Following are some **suggested** functions with the pseudocode provided. You can create/remove functions as needed.

# %%
# return True if the input move (from-square and to-square) is legal, else False
# this is the KEY function which contains the rules for each piece type 
'''
def get_piece_position_score(board, piece, table):
        player0 = 0
        player1 = 0
        for x in range(8):
            for y in range(8):
                piece = board.chesspieces[x][y]
                if (piece != 0):
                    if (piece.piece_type == piece_type):
                        if (piece.color == pieces.Piece.WHITE):
                            player0 += table[x][y]
                        else:
                            player1 += table[7 - x][y]
        #print(player0)
        #print(player1)                    
        return player0 - player1
'''   
#checking the legal moves for each piece.
def IsMoveLegal(current_player,from_square,to_square):
    
    from_piece = board[from_square[0],from_square[1]]
    to_piece =  board[to_square[0],to_square[1]]
    difference_row = to_square[0] - from_square[0]
    difference_col = to_square[1] - from_square[1]
    
    #print("is movelegal", from_piece, to_piece)
    
    # input is from-square and to-square
    # use the input and the board to get the from-piece and to-piece
    
    if from_square == to_square:
        return False
    
    elif ((from_piece == 'p' and current_player == 0) or (from_piece == 'P' and c_player == 1)):
        ## case - pawn wants to move one step forward (or backward if white)
        # if to-square is empty and is in the same column as the from-square
            # return True
          
          if difference_row == 1 and difference_col == 0: #one
                if from_piece == 'p':
                    if to_piece == '.':
                      return True
          elif difference_row == -1 and difference_col == 0:
                if from_piece == 'P':
                    #print("P1")
                    if to_piece == '.':
                      return True
        
        ## case - pawn can move two spaces forward (or backward if white) ONLY if pawn on starting row
        # else if to-square is empty and from-square-row = 2 (or 7 if white) and to-square-row = from-square-row + 2 (or -2 if white)
            # if IsClearPath() - a clear path exists between from-square and to-square
                # return True
          elif difference_row == 2 and difference_col == 0: #two
                if from_piece == 'p' and current_player == 0:
                    if from_square[0] == 1 and to_piece == '.':
                          if IsClearPath(from_square,to_square ) :
                              return True
          elif difference_row == -2 and difference_col == 0: 
                if from_piece == 'P' and current_player == 1:
                    # if IsClearPath() - a clear path exists between from-square and to-square
                    # return True
                    if from_square[0] == 6 and to_piece == '.':
                          if IsClearPath(from_square,to_square ):
                              return True
         
        
        ## case - pawn attacks the enemy piece if diagonal
        # else if there is piece diagonally forward (or backward if white) and that piece belongs to the enemy team
            # return True
          elif difference_row == 1 and abs(difference_col) == 1: 
               if from_piece == 'p' and current_player == 0:
                    if to_piece.isupper() == True:
                         return True
          elif difference_row == -1 and abs(difference_col) == 1:
               if from_piece == 'P' and current_player == 1:
                    if to_piece.islower() == True:
                         return True
          else:
            return False
    #else if the from-piece is a "rook"
    elif ((from_piece == 'r' and current_player == 0) or (from_piece == 'R' and current_player == 1)):
        #if to-square is either in the same row or column as the from-square
          if (difference_row) == 0 or (difference_col) == 0:
              # if to-square is either empty or contains a piece that belongs to the enemy team
              if (to_piece == '.') or (check_update(from_piece, to_piece) == True):
                  #if IsClearPath() - a clear path exists between from-square and to-square
                   if IsClearPath(from_square,to_square ):
                          return True
                 

    # else if the from-piece is a "bishop"
    elif ((from_piece == 'b' and current_player == 0) or (from_piece == 'B' and current_player == 1)):
          right_from = from_square[0] + from_square[1]
          right_to = to_square[0] + to_square[1]
          left_from = abs(from_square[0] - from_square[1])
          left_to = abs(to_square[0] - to_square[1])
          # if to-square is diagonal wrt from-square
          if (right_from == right_to) or (left_from  == left_to):
              # if to-square is either empty or contains a piece that belongs to the enemy team
              if (to_piece == '.') or (check_update(from_piece, to_piece) == True):
                  # if IsClearPath() - a clear path exists between from-square and to-square
                  if IsClearPath(from_square,to_square ):
                      return True
               

    elif ((from_piece == 'q' and current_player == 0) or (from_piece == 'Q' and current_player == 1)):
          #Right diagonal
          right_from = from_square[0] + from_square[1]
          right_to = to_square[0] + to_square[1]
          #Left Diagonal
          left_from = abs(from_square[0] - from_square[1])
          left_to = abs(to_square[0] - to_square[1])
          # if to-square is either in the same row or column as the from-square
          if ((abs(difference_row) == 0) or (abs(difference_col) == 0)):
              # if to-square is either empty or contains a piece that belongs to the enemy team
              if (to_piece == '.') or (check_update(from_piece, to_piece) == True):
                  # if IsClearPath() - a clear path exists between from-square and to-square
                  if IsClearPath(from_square,to_square ):
                      return True
                  
          ## SAME as "bishop"
          elif (right_from == right_to) or (left_from  == left_to):
            # if to-square is either empty or contains a piece that belongs to the enemy team
              if (to_piece == '.') or (check_update(from_piece, to_piece) == True):
                # if IsClearPath() - a clear path exists between from-square and to-square
                  if IsClearPath(from_square,to_square ):
                      return True
                  

    elif ((from_piece == 't' and current_player == 0) or (from_piece == 'T' and current_player == 1)):

          # if to-square is either empty or contains a piece that belongs to the enemy team
          if ((to_piece == '.') or (check_update(from_piece, to_piece) == True)): 
               # return True for any of the following cases:
                if difference_col == 1 and difference_row == -2:
                  return True
                elif difference_col == 2 and difference_row == -1:
                  return True
                elif difference_col == 2 and difference_row == 1:
                  return True
                elif difference_col == 1 and difference_row == 2:
                  return True
                elif difference_col == -1 and difference_row == -2:
                  return True
                elif difference_col == -2 and difference_row == -1:
                  return True
                elif difference_col == -2 and difference_row == 1:
                  return True
                elif difference_col == -1 and difference_row == 2:
                  return True

    elif ((from_piece == 'k' and current_player == 0) or (from_piece == 'K' and current_player == 1)):
          # calculate the col-diff = to-square-col - from-square-col
          # calculate the row-diff = to-square-row - from-square-row
          # if to-square is either empty or contains a piece that belongs to the enemy team
          if (to_piece == '.') or (check_update(from_piece, to_piece) == True):
              # return True for any of the following cases:
                  # abs(col-diff) = 1 & abs(row_dif) = 0
                  if abs(difference_col) == 1 and abs(difference_row) == 0:
                    return True
                  # abs(col-diff) = 0 & abs(row_dif) = 1
                  elif abs(difference_col) == 0 and abs(difference_row) == 1:
                    return True
                  # abs(col-diff) = 1 & abs(row_dif) = 1
                  elif abs(difference_col) == 1 and abs(difference_row) == 1:
                    return True

    else:
      return False

def check_update(from_point, to_point):
       if to_point == ".":
          return False
       elif ((from_point.islower() == True and to_point.isupper() == True) or (from_point.isupper() == True and to_point.islower() == True)):
          return True 
       else:
          return False

# # gets a list of legal moves for a given piece
# # input = from-square
# # output = list of to-square locations where the piece can move to
def GetListOfLegalMoves(c_player,from_square):
    # input is the current player and the given piece as the from-square
    # initialize the list of legal moves, i.e., to-square locations to []
    MovelegalList = []
    # go through all squares on the board
    for i in range(8):
        for j in range(8):
    # for the selected square as to-square
            to_square = [i,j]
            # call IsMoveLegal() with input as from-square and to-square and save the returned value
            legal_value = IsMoveLegal(c_player, from_square, to_square)
            if legal_value == True:
                  #DoesMovePutPlayerInCheck(from_square, to_square) with input as from-square and to-square and save the returned value
                  val_check = DoesMovePutPlayerInCheck(from_square, to_square, c_player)
              # if returned value is False
              # append this move (to-square) as a legal move
                  if val_check == False:
                      MovelegalList.append(to_square)
    # return the final list of pieces with legal moves
    return MovelegalList

# gets a list of all pieces for the current player that have legal moves
def GetPiecesWithLegalMoves(c_player):
    # initialize the list of pieces with legal moves to []
    LegalpiecesList = []
    # go through all squares on the board
    for i in range(len(board)):
      for j in range(len(board)):
        # for the selected square
        # if the square contains a piece that belongs to the current player's team
        if((c_player == 0 and (board[i][j]).islower()) or (c_player == 1 and (board[i][j]).isupper())):
            # call GetListOfLegalMoves() to get a list of all legal moves for the selected piece / square
            moves = GetListOfLegalMoves(c_player, [i,j])
            # if there are any legel moves
            if len(moves)>0:
                # append this piece to the list of pieces with legal moves
                LegalpiecesList.append([board[i,j],[i,j]])
                
    # return the final list of pieces with legal moves
    return LegalpiecesList



# returns True if the current player is in checkmate, else False
def IsCheckmate(c_player):
    # call GetPiecesWithLegalMoves() to get all legal moves for the current player
    legal_move = GetPiecesWithLegalMoves(c_player)
    # if there is no piece with any valid move
    if len(legal_move)<0:
        # return True
        return True
    # else
        # return False
    else:
        return False


# returns True if the given player is in Check state
def IsInCheck(c_player):

      king_square=[]
    # find given player's King's location = king-square
      if c_player == 0:
          pos = np.where(board=='k')
          #print("ISIN0: ", pos)
          [i,j] = pos
          king_square.append(i[0])
          king_square.append(j[0])
      elif c_player == 1:
          pos = np.where(board=='K')
          [i,j] = pos
          king_square.append(i[0])
          king_square.append(j[0])
    

      # go through all squares on the board
      for i in range(8):
          for j in range(8):
            # if there is a piece at that location and that piece is of the enemy team
               # elif ((c_player == 0 and (board[i][j]).isupper()) or (c_player == 1 and (board[i][j]).islower())):
               if ((board[i][j]) == "."):
                 return False
               elif ((c_player == 0 and (board[i][j]).isupper()) or (c_player == 1 and (board[i][j]).islower())):       
            # call IsMoveLegal() for the enemy player from that square to the king-square
                          legal = IsMoveLegal(c_player,[i,j],king_square)
            # if the value returned is True
                          if legal == True:
                      # return True
                            return True
                          else:
                            continue
                   # else
    # return False at the end
      return False


# helper function to figure out if a move is legal for straight-line moves (rooks, bishops, queens, pawns)
# returns True if the path is clear for a move (from-square and to-square), non-inclusive
#*********

'''
def minimax(board_state, heuristic, next_moves, current_depth=0, max_depth=4):
    current_depth += 1
    if current_depth == max_depth:
        # get heuristic of each node
        return next(heuristic)
    if current_depth % 2 == 0:
        # min player's turn
        return min([minimax(node, heuristic, current_depth, max_depth) for node in next_moves()])
    else:
        # max player's turn
        return max([minimax(node, heuristic, current_depth, max_depth) for node in next_moves()])
'''

# helper function to figure out if a move is legal for straight-line moves (rooks, bishops, queens, pawns)
# returns True if the path is clear for a move (from-square and to-square), non-inclusive
#*********
def IsClearPath(new_from_square, new_to_square):
    # given the move (from-square and to-square)
    from_square = new_from_square[:]
    to_square = new_to_square[:]

    row_diff = to_square[0] - from_square[0]
    col_diff = to_square[1] - from_square[1]

    from_sum = from_square[0] + from_square[1]
    to_sum = to_square[0] + to_square[1]

    from_sub = abs(from_square[0] - from_square[1])
    to_sub = abs(to_square[0] - to_square[1])
    # if the from and to squares are only one square apart
    # return True
    if ((abs(row_diff) == 1 or abs(row_diff) == 0)  and (abs(col_diff) == 1 or abs(col_diff) == 0)):
        return True
    # else
    else:
       # if to-square is in the +ve vertical direction from from-square
          if row_diff <-1 and col_diff == 0:
               # new-from-square = next square in the +ve vertical direction
               from_square[0] = from_square[0] - 1
               from_square[1] = from_square[1]
           # else if to-square is in the -ve vertical direction from from-square
          elif row_diff > 1 and col_diff == 0:
            # new-from-square = next square in the -ve vertical direction
               from_square[0] = from_square[0] + 1
               from_square[1] = from_square[1]
          # else if to-square is in the +ve horizontal direction from from-square
          elif col_diff > 1 and row_diff == 0:
            # new-from-square = next square in the +ve horizontal direction
               from_square[0] = from_square[0]
               from_square[1] = from_square[1] + 1
            
        # else if to-square is in the -ve horizontal direction from from-square
          elif col_diff < -1 and row_diff == 0:
            # new-from-square = next square in the -ve horizontal direction
               from_square[0] = from_square[0]
               from_square[1] = from_square[1] - 1
        
        # else if to-square is in the NE diagonal direction from from-square
          elif ((to_square[0] < from_square[0])  and (from_sum == to_sum)):
        # new-from-square = next square in the NE diagonal direction
              from_square[0] = from_square[0] - 1
              from_square[1] = from_square[1] + 1
            
        # else if to-square is in the NW diagonal direction from from-square
          elif ((to_square[0] < from_square[0]) and (from_sub == to_sub)):
            # new-from-square = next square in the NW diagonal directionml
              from_square[0] = from_square[0] - 1
              from_square[1] = from_square[1] - 1
        # else if to-square is in the SE diagonal direction from from-square
          elif ((to_square[0] > from_square[0])  and (from_sub == to_sub)):
              # new-from-square = next square in the SE diagonal direction
              from_square[0] = from_square[0] + 1
              from_square[1] = from_square[1] + 1
        # else if to-square is in the SW diagonal direction from from-square
          elif ((to_square[0] > from_square[0]) and (from_sum == to_sum)):
              # new-from-square = next square in the SW diagonal direction
              from_square[0] = from_square[0] + 1
              from_square[1] = from_square[1] - 1

 
    # if new-from-square is not empty
        # return False
    if (from_square[0] < 8 and from_square[1] < 8):
        if board[from_square[0]][from_square[1]] != '.' :
          return False
    # else
        # return the result from the recursive call of IsClearPath() with the new-from-square and to-square
        else:
          return IsClearPath(from_square,to_square)
    else:
      return False


# makes a hypothetical move (from-square and to-square)
# returns True if it puts current player into check
def DoesMovePutPlayerInCheck(from_square, to_square,c_player):
    # given the move (from-square and to-square), find the 'from-piece' and 'to-piece'
    from_piece = board[from_square[0],from_square[1]]
    to_piece =  board[to_square[0],to_square[1]]
    # make the move temporarily by changing the 'board'
    temp1 = from_piece
    temp2 = to_piece
    board[to_square[0],to_square[1]] = temp1
    board[from_square[0], from_square[1]] = '.'
    # Call the IsInCheck() function to see if the 'player' is in check - save the returned value
    DoesMovePutPlayerInCheck = IsInCheck(c_player)
    # Undo the temporary move
    board[from_square[0],from_square[1]] = temp1
    board[to_square[0],to_square[1]] = temp2
    # return the value saved - True if it puts current player into check, False otherwise
    #print(DoesMovePutPlayerInCheck)
    return DoesMovePutPlayerInCheck

# %% [markdown]
# #Artificial Intelligence
#
# In this section, you will write code for the Artificial Intelligence (AI) that will play a game of chess. You will write 2 types of AI:
#
# 1.   **RandomAI** - This part will contain code for moving a chess piece randomly.
# 2.   **MinMaxAI** - This part will contain code for moving a chess piece using the MinMax strategy discussed in the lecture.

# %% [markdown]
# ##RandomAI
#
# (10 points)
#
# Complete the function below that will perform a random move for the given player. The function will return the move (from-piece and to-piece). You will most likely not need to write any other function, but you can, if needed.

# %%
#function for random move
def GetRandomMove(current_p):
    # pick a random piece and a random legal move for that piece
     random_peice_list = random.choice(GetPiecesWithLegalMoves(current_p))
     random_move = random.choice(GetListOfLegalMoves(current_p,random_peice_list[1]))
     print(random_move)
GetRandomMove(0)
# Out:
# [3, 2]

# %% [markdown]
# ##MinMaxAI
#
# (60 points)
#
# Complete the functions below that will perform a move for the given player using the MinMax AI strategy. One function will evaluate the board if a move is performed - give score for each of piece and calculate the score for the entire chess board. In the second function you will write actual code for the MinMax strategy and return the move (from-piece and to-piece). To get the allocated points, searching should be **2-ply (one Max and one Min)**. You will most likely not need to write any other function, but you can, if needed.
#
# ## Extra Credit
#
# *   **(5 points)** Modify the above MinMax strategy to be **4-ply (one Max, one Min, one Max, one Min)**.
# *   **(15 points)** Perform **alpha-beta pruning** for the MinMax strategy.

# %%
'''
def minimax(depth, board, alpha, beta, is_maximizing):
    if(depth == 0):
        return -evaluation(board)
    possibleMoves = board.legal_moves
    if(is_maximizing):
        bestMove = -9999
        for x in possibleMoves:
            move = chess.Move.from_uci(str(x))
            board.push(move)
            bestMove = max(bestMove,minimax(depth - 1, board,alpha,beta, not is_maximizing))
            board.pop()
            alpha = max(alpha,bestMove)
            if beta <= alpha:
                return bestMove
        return bestMove
    else:
        bestMove = 9999
        for x in possibleMoves:
            move = chess.Move.from_uci(str(x))
            board.push(move)
            bestMove = min(bestMove, minimax(depth - 1, board,alpha,beta, not is_maximizing))
            board.pop()
            beta = min(beta,bestMove)
            if(beta <= alpha):
                return bestMove
        return bestMove
'''

#putting values in the pieces in the chess for evaluation.
def getPieceValue(piece, current_player):
    if(piece == "k" or  piece =="K" or  piece == "."):
        return 0
    value = 0
    if piece == "P" or piece == "p":
        value = 10
    if piece == "T" or piece == "t":
        value = 35
    if piece == "B" or piece == "b":
        value = 30
    if piece == "R" or piece == "r":
        value = 50
    if piece == "Q" or piece == "q":
        value = 70
    return value

#evaluation function
def evl(current_player):
    # this function will calculate the score on the board, if a move is performed
    # give score for each of piece and calculate the score for the chess board
    evaluation_score = 0
    for i in range(8):
      for j in range (8):
              if(current_player == 0):
                  #print(board[i][j])
                  #checking if lower
                  if board[i][j].islower():
                      evaluation_score = evaluation_score - getPieceValue(board[i][j], current_player)
                
              elif(current_player == 1):
                  #print(board[i][j])
                  #checking if higher
                  if board[i][j].isupper():
                      evaluation_score = evaluation_score + getPieceValue(board[i][j], current_player)
    #returning the evaluation_score                     
    return evaluation_score

##minmax function
maxDepth = 2
def GetMinMaxMove(board, current_player, depth, maxDepth):
    if ( depth == maxDepth ):
              return evl(current_player)
    foundMove = None
    if current_player == 0:
          highestscore = math.inf
    else:
         highestscore = - math.inf
    #finding the pieces for the player
    pieces = GetPiecesWithLegalMoves(current_player)
    # iterating pieces 
    for piece in pieces:
        #print("here")
        #print(piece)
        # moves = GetListOfLegalMoves(curPlayer, piece)
        # moves = GetListOfLegalMoves(curPlayer, piece)
        moves = GetListOfLegalMoves(current_player, piece[1])
        for move in moves:
            newBoard = MovePiece(piece[1],move)       
            #score     
            score = GetMinMaxMove(newBoard, current_player, depth+1, maxDepth)
            #maximizing 
            if (current_player == 1):
               if score > highestscore:
                highestscore = score
                foundMove = move
                #print(board)
            else:
              #minimizing
              if score < highestscore:
                highestscore = score
                foundMove = move
    #print(board)
    #print(highestscore) 
    #returning the highestscore      
    return highestscore

# %% [markdown]
# #Game Setup & Main Loop
#
# (10 points)
#
# Write code below to have a game-play between two AIs - Random vs MinMax. For each iteration, draw the board before and after a turn.

# %%
# initialize and setup the board
# player assignment and counter initializations

# main game loop - while a player is not in checkmate or stalemate (<N turns)
# below is the rough looping strategy
count = 0
turns = 0

#selecting the number of turns 100
while turns < 100:
    
    clear_output()
    # write code to take turns and move the pieces
    #0 for player 1
    if turns%2 == 0:
        #for player 0
        GetMinMaxMove(board,0,0,2)
        count =1
    else:
        if (("K" in board) == False):
          break
        else:
          #for player 1
          GetMinMaxMove(board,1,0,2)
          count = 0
    turns +=1
    time.sleep(0.5)

# check and print - Stalemate or Checkmate
print("Current condition of the chess board\n")
print(board)
player1 = []
player2 = []

#checking the baord now for the remaing pieces
for i in range(len(board)):
  for j in range(len(board)):
    if ((board[i][j]) != "."):
       #black player has the peices with lower letters 
       if ((board[i][j]).islower() == True):
           player1.append(board[i][j])
       #white player has the peices with higher letters    
       elif ((board[i][j]).isupper() == True):
           player2.append(board[i][j])

print("\n")
print("Black Player has pieces ", player1)        
print("White Player has pieces ", player2)
# Out:
# Current condition of the chess board
#
# [['q' 'k' '.' '.' 't' '.' '.' '.']
#  ['r' 'b' 't' 'b' '.' '.' '.' '.']
#  ['.' 'r' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.' '.']
#  ['.' 'p' '.' '.' '.' '.' '.' '.']
#  ['p' 'T' '.' 'p' 'p' 'p' 'p' 'p']]
#
#
# Black Player has pieces  ['q', 'k', 't', 'r', 'b', 't', 'b', 'r', 'p', 'p', 'p', 'p', 'p', 'p', 'p']
# White Player has pieces  ['T']

# %% [markdown]
# #Submission Instructions
#
# 1.   Complete all tasks above - **File MUST contain the output for ALL cells**
# 2.   Export this notebook as .ipynb
#       (File > Download as ipynb)
# 3.   Upload the .ipynb file on Blackboard

# %% [markdown]
# ##Rubric
#
# *   (10 points) Chess Board Setup
# *   (60 points) Chess Rules Setup
# *   (10 points) Random AI
# *   (60 points) MinMax AI (2-ply)
# *   (10 points) Game Main Loop - Random vs MinMax
# *   (20 points) Extra Credit - 4-ply MinMax + alpha-beta pruning
